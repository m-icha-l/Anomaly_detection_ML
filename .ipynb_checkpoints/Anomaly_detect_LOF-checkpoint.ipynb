# %%
from sklearn.neighbors import LocalOutlierFactor
import pandas as pd
import matplotlib.pyplot as plt  
import numpy as np
import logging
from funs import *

log("START",level = ("start","Local_Outlier_Factor"))
# Out:
# Local_Outlier_Factor

# %% [markdown]
# <div style="margin-left: 38px; font-size: 30px; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; margin-top: 20px; line-height: 1.6;">
#     <div>Impot danych z wcześniejszego parsowania w Anomaly_detect_ML</div>
# </div>

# %%
df_1_scaled = pd.read_hdf('parsed_data/segmented_CICIDS2017.h5', key='df_1_scaled')
df_scaled = pd.read_hdf('parsed_data/merged_CICIDS2017.h5', key='df_scaled')
df_labels = pd.read_hdf('parsed_data/merged_CICIDS2017.h5', key='df_labels')
print(df_1_scaled.columns)
print(df_scaled.columns)

for i in range(len(df_scaled.columns)):
    if(df_1_scaled.columns[i] == df_scaled.columns[i]):
        print("ok")
    else:
        print("err")
print(df_1_scaled.columns.equals(df_scaled.columns))
print(type(df_scaled), type(df_1_scaled))
# Out:
# Index(['Flow Duration', 'Total Fwd Packets', 'Total Backward Packets',
#        'Total Length of Fwd Packets', 'Total Length of Bwd Packets',
#        'Fwd Packet Length Max', 'Fwd Packet Length Min',
#        'Fwd Packet Length Mean', 'Fwd Packet Length Std',
#        'Bwd Packet Length Max', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow IAT Mean',
#        'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total',
#        'Repetition num'],
#       dtype='object')
# Index(['Flow Duration', 'Total Fwd Packets', 'Total Backward Packets',
#        'Total Length of Fwd Packets', 'Total Length of Bwd Packets',
#        'Fwd Packet Length Max', 'Fwd Packet Length Min',
#        'Fwd Packet Length Mean', 'Fwd Packet Length Std',
#        'Bwd Packet Length Max', 'Bwd Packet Length Mean',
#        'Bwd Packet Length Std', 'Flow Bytes/s', 'Flow IAT Mean',
#        'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Total',
#        'Repetition num'],
#       dtype='object')
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# True
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <div style="margin-left: 38px; font-size: 30px; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; margin-top: 20px; line-height: 1.6;">
#     <div>Treming modelu</div>
# </div>

# %%
LOF= LocalOutlierFactor(
    n_neighbors=20,
    algorithm='auto',
    leaf_size=30,
    metric='minkowski',
    p=2,
    metric_params=None,
    contamination='auto',
    novelty=True,
    n_jobs=None
)
LOF.fit(df_1_scaled)
# Out:
# LocalOutlierFactor(novelty=True)

# %% [markdown]
# <div style="margin-left: 38px; font-size: 30px; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif; margin-top: 20px; line-height: 1.6;">
#     <div>Treming modelu</div>
# </div>

# %%
df_scaled_result_check = test_LOF_model(LOF,df_scaled,df_labels, name="test_1")
# Out:
# /root/Anomaly_Detection/venv_AD/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# /root/Anomaly_Detection/venv_AD/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(
# no_name
# Detection distribution anomaly/normal: 35.8910% / 64.1090%
# !!! Wyniki pokazuje dopasowanie contamination (wyciagania wnioskow z gotowego produktu pracy modelu) NIE DCHYLENIA NORMALNY/ANOMALYJNY ruch sieciowy !!!
# Anomaly detected: 601890
# Normal traffic: 1075103
# no_name
# Number of flows in test_1: 1676993
# Correct data:
# Real number of anomalies in test_1: 335370
# Procentage of anomlys in dataset: 19.9983%
# Predicted data:
# Number of DETECTED anomalies in test_1: 601890
# Procentage of anomlys in dataset: 35.8910%
#
# Number of correct predictions(TP): 297679
# Number of wrong predyctions(FP): 304211
# Accuracy of predictions: 79.6122%
# Sensitivity of predictions: 88.7614%
# Precision of predictions: 49.4574%
# F - mesure - harmonic-mean of precision and sensitivity: 63.5211%

# %%
test_model(name="test_1",level = ["start","LOF_ready"],ready = df_scaled_result_check, flag = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 test_model(name="test_1",level = ["start","LOF_ready"],ready = df_scaled_result_check, flag = True)
#
# TypeError: test_model() got an unexpected keyword argument 'flag'
